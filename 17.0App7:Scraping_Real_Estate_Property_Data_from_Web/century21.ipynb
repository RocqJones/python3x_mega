# %%
"""
    I will web scrape a real estate website and store data in a pandas data-frame or export it in an csv output.
    From there I can choose how to present it graphically.
    url = http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS
    Note that the above url is a cache or the website since it has changed.
    You'll notice the data is in 3 pages so we will crawl all of them.
    Sometimes you might get kicked out of the website so make sure you it for educational purposes.
"""

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS"

r = requests.get(url)
c = r.content

# make it readable. If you're using a txt editor when you're done with print() below just comment it
soup = BeautifulSoup(c, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-usagetrack-config='{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}' lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="Rock Springs Real Estate | Find Houses &amp; Homes for Sale in Rock Springs, WY" name="title"/>
#   <meta content="Search Rock Springs real estate property listings to find homes for sale in Rock Springs, WY. Browse houses for sale in Rock Springs today!" name="description">
# ...

# %%
all_p = soup.findAll("div",{"class":"propertyRow"})

# %%
all
# Out:
# []

# %%
len(all)
# Out:
# 0

# %%
all[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-f5a6838faac1> in <module>
# ----> 1 all[0]
#
# IndexError: list index out of range

# %%
all[0].find_all("h4",{"class":"propPrice"})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-d1a599ae4505> in <module>
# ----> 1 all[0].find_all("h4",{"class":"propPrice"})
#
# IndexError: list index out of range

# %%
all[0].find("h4",{"class":"propPrice"}).text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-5b423e8f0904> in <module>
# ----> 1 all[0].find("h4",{"class":"propPrice"}).text
#
# IndexError: list index out of range

# %%
# you'll find it's a string method so we parse string methods below to remove the "\n"
type(all[0].find("h4",{"class":"propPrice"}).text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-f1b400f7d082> in <module>
#       1 # you'll find it's a string method so we parse string methods to remove the "\n"
# ----> 2 type(all[0].find("h4",{"class":"prop"}).text)
#
# IndexError: list index out of range

# %%
# remove \n and " " white space
all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-bd3b35447e38> in <module>
#       1 # remove \n and " " white space
# ----> 2 all[0].find("h4",{"class":"prop"}).text.replace("\n","").replace(" ","")
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.century21.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS"

r = requests.get(url)
c = r.content

soup = BeautifulSoup(c, "html.parser")
# print(soup.prettify())

all = soup.find_all("div",{"class":"propertyRow"})
len(all)

# all[0].find("h4",{"class":"propPrice"}).text
# type(all[0].find("h4",{"class":"propPrice"}).text)
while True:    
    try:
        all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
    except IndexError:
        all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-db884dae8f35> in <module>
#      17 while True:
#      18     try:
# ---> 19         all.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
#      20     except IndexError:
#      21         all.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# ...

# %%
import requests, re
from bs4 import BeautifulSoup

r=requests.get("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"propertyRow"})

all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ","")

page_nr=soup.find_all("a",{"class":"Page"})[-1].text
print(page_nr,"number of pages were found")
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1639                         raise SysCallError(errno, errorcode.get(errno))
# -> 1640                 raise SysCallError(-1, "Unexpected EOF")
#    1641             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# ...
