# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Floor5EMARA.xlsx',
#  'supermarkets_comma.txt',
#  'supermarkets.json',
#  '4.1data_analysis_with_pandas.ipynb',
#  '4.2loading_data_indexing_and_slicing_DF.ipynb',
#  '4.3Dropping_rows_and_columns.ipynb',
#  '4.4updating_and_adding_new_rows_columns.ipynb']

# %%
import pandas

# %%
df = pandas.read_json("supermarkets.json")
df
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#       State
# 0  CA 94114
# 1  CA 94119
# 2  CA 94114
# 3  CA 94114
# 4  CA 89446
# 5  CA 94114

# %%
df = df.set_index("Address")

# %%
df
# Out:
#                           City Country  Employees  ID         Name     State
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira  CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop  CA 94119
# 332 Hill St      San Francisco     USA         25   3  Super River  CA 94114
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop  CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  CA 89446
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley  CA 94114

# %%
# check length or row
len(df.index)
# Out:
# 6

# %%
df.shape # (rows,col)
# Out:
# (6, 6)

# %%
df["County"]=df.shape[0]*["Rift Valley"]

# %%
df
# Out:
#                           City Country  Employees  ID         Name     State  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira  CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop  CA 94119
# 332 Hill St      San Francisco     USA         25   3  Super River  CA 94114
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop  CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  CA 89446
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley  CA 94114
#
#                    Continent       County
# Address
# 3666 21st St     Rift Valley  Rift Valley
# 735 Dolores St   Rift Valley  Rift Valley
# 332 Hill St      Rift Valley  Rift Valley
# 3995 23rd St     Rift Valley  Rift Valley
# 1056 Sanchez St  Rift Valley  Rift Valley
# 551 Alvarado St  Rift Valley  Rift Valley

# %%
df.shape[0]*["Rift Valley"]
# Out:
# ['Rift Valley',
#  'Rift Valley',
#  'Rift Valley',
#  'Rift Valley',
#  'Rift Valley',
#  'Rift Valley']

# %%
# updating
df["County"]=df["Country"] + "," + "Rift Valley"

# %%
df
# Out:
#                           City Country  Employees  ID         Name     State  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira  CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop  CA 94119
# 332 Hill St      San Francisco     USA         25   3  Super River  CA 94114
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop  CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  CA 89446
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley  CA 94114
#
#                    Continent           County
# Address
# 3666 21st St     Rift Valley  USA,Rift Valley
# 735 Dolores St   Rift Valley  USA,Rift Valley
# 332 Hill St      Rift Valley  USA,Rift Valley
# 3995 23rd St     Rift Valley  USA,Rift Valley
# 1056 Sanchez St  Rift Valley  USA,Rift Valley
# 551 Alvarado St  Rift Valley  USA,Rift Valley

# %%
df = df.drop("Continent",1) # Drop it completely

# %%
df
# Out:
#                           City Country  Employees  ID         Name     State  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira  CA 94114
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop  CA 94119
# 332 Hill St      San Francisco     USA         25   3  Super River  CA 94114
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop  CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez  CA 89446
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley  CA 94114
#
#                           County
# Address
# 3666 21st St     USA,Rift Valley
# 735 Dolores St   USA,Rift Valley
# 332 Hill St      USA,Rift Valley
# 3995 23rd St     USA,Rift Valley
# 1056 Sanchez St  USA,Rift Valley
# 551 Alvarado St  USA,Rift Valley

# %%
# Transform table: Make rows become col and col become rows.
df_t=df.T

# %%
df_t
# Out:
# Address       3666 21st St   735 Dolores St      332 Hill St     3995 23rd St  \
# City         San Francisco    San Francisco    San Francisco    San Francisco
# Country                USA              USA              USA              USA
# Employees                8               15               25               10
# ID                       1                2                3                4
# Name               Madeira      Bready Shop      Super River       Ben's Shop
# State             CA 94114         CA 94119         CA 94114         CA 94114
# County     USA,Rift Valley  USA,Rift Valley  USA,Rift Valley  USA,Rift Valley
#
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Country                USA              USA
# Employees               12               20
# ID                       5                6
# Name               Sanchez       Richvalley
# State             CA 89446         CA 94114
# ...

# %%
df_t["My Address"]=["Nairobi","Kenya",10,7,"Rocq Shop","KT 92100","Kitui"]

# %%
df=df_t.T

# %%
df
# Out:
#                           City Country Employees ID         Name     State  \
# Address
# 3666 21st St     San Francisco     USA         8  1      Madeira  CA 94114
# 735 Dolores St   San Francisco     USA        15  2  Bready Shop  CA 94119
# 332 Hill St      San Francisco     USA        25  3  Super River  CA 94114
# 3995 23rd St     San Francisco     USA        10  4   Ben's Shop  CA 94114
# 1056 Sanchez St  San Francisco     USA        12  5      Sanchez  CA 89446
# 551 Alvarado St  San Francisco     USA        20  6   Richvalley  CA 94114
# My Address             Nairobi   Kenya        10  7    Rocq Shop  KT 92100
#
#                           County
# Address
# 3666 21st St     USA,Rift Valley
# 735 Dolores St   USA,Rift Valley
# 332 Hill St      USA,Rift Valley
# 3995 23rd St     USA,Rift Valley
# 1056 Sanchez St  USA,Rift Valley
# 551 Alvarado St  USA,Rift Valley
# My Address                 Kitui
